# %% [markdown]
# <a href="https://colab.research.google.com/github/jess22jess/SIMULACI-N-II/blob/main/N%C3%BAmeros_Aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def generador(a, b, m, x0):
    x1 = (a*x0 + b)%m
    return x1

# %%
a = 7
b = 5
m = 32
x0 = 0
n = 10
muestra = []
for i in range(n):
    nuevo = generador(a, b, m,x0=nuevo)
    muestra.append(nuevo)
print(muestra)
# Out:
# [0.625, 0.53125, 0.875, 0.28125, 0.125, 0.03125, 0.375, 0.78125, 0.625, 0.53125]
